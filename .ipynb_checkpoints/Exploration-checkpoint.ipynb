# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
from copy import deepcopy

# %%
ts = TimeSeries(key='IX5ZSV7I3UUZ3I5B', output_format='csv')

# %%
data_reader, _ = ts.get_intraday_extended('SPY', interval='30min', slice='year1month1')

# %%
df = pd.DataFrame(data_reader)
df, df.columns = df[1:] , df.iloc[0]

# %%
df['time'] = pd.to_datetime(df['time'])
for c in ['open','high','low','close','volume']:
    df[c] = pd.to_numeric(df[c])

# %%
df = df.set_index('time').between_time('09:30:00','16:00:00').sort_index()

# %%
df.reset_index(drop=True)['close'].plot()

# %%
df2 = df.copy()
df2['date'] = pd.to_datetime(df2.index.date)

# %%
df2
# Out:
# 0                       open    high      low     close   volume       date
# time
# 2020-12-24 09:30:00  368.150  368.18  367.960  368.0400    70056 2020-12-24
# 2020-12-24 10:00:00  368.080  368.56  367.970  368.4000  2679519 2020-12-24
# 2020-12-24 10:30:00  368.410  368.69  368.250  368.6009  1813834 2020-12-24
# 2020-12-24 11:00:00  368.605  368.72  368.150  368.1900  1512576 2020-12-24
# 2020-12-24 11:30:00  368.190  368.54  367.960  367.9800  2712708 2020-12-24
# ...                      ...     ...      ...       ...      ...        ...
# 2021-01-22 14:00:00  383.430  383.73  383.210  383.2200  1148244 2021-01-22
# 2021-01-22 14:30:00  383.225  383.50  383.025  383.2850  2241273 2021-01-22
# 2021-01-22 15:00:00  383.290  383.76  383.230  383.7300  2185120 2021-01-22
# 2021-01-22 15:30:00  383.732  383.91  383.160  383.8800  2880245 2021-01-22
# 2021-01-22 16:00:00  383.870  384.08  382.800  382.8600  6378102 2021-01-22
#
# [262 rows x 6 columns]

# %%
date_range = pd.date_range(df2.index.date.min(), df2.index.date.max())
index = np.arange(1,len(date_range)+1)
date_range_df = pd.DataFrame({
    'date': date_range,
    'day_index': index
})

# %%
df2.reset_index().merge(date_range_df, on='date', how='left')
# Out:
#                    time     open    high      low     close   volume  \
# 0   2020-12-24 09:30:00  368.150  368.18  367.960  368.0400    70056
# 1   2020-12-24 10:00:00  368.080  368.56  367.970  368.4000  2679519
# 2   2020-12-24 10:30:00  368.410  368.69  368.250  368.6009  1813834
# 3   2020-12-24 11:00:00  368.605  368.72  368.150  368.1900  1512576
# 4   2020-12-24 11:30:00  368.190  368.54  367.960  367.9800  2712708
# ..                  ...      ...     ...      ...       ...      ...
# 257 2021-01-22 14:00:00  383.430  383.73  383.210  383.2200  1148244
# 258 2021-01-22 14:30:00  383.225  383.50  383.025  383.2850  2241273
# 259 2021-01-22 15:00:00  383.290  383.76  383.230  383.7300  2185120
# 260 2021-01-22 15:30:00  383.732  383.91  383.160  383.8800  2880245
# 261 2021-01-22 16:00:00  383.870  384.08  382.800  382.8600  6378102
#
#           date  day_index
# 0   2020-12-24          1
# 1   2020-12-24          1
# 2   2020-12-24          1
# 3   2020-12-24          1
# 4   2020-12-24          1
# ..         ...        ...
# 257 2021-01-22         30
# 258 2021-01-22         30
# 259 2021-01-22         30
# 260 2021-01-22         30
# 261 2021-01-22         30
#
# [262 rows x 8 columns]

# %%
TRADER_START_AMT = 100
POP_SIZE = 50
EPOCHS = 100

# %%
def init_strategy():
    return {
        'inc_trigger_pct': np.random.uniform(low=0.01, high=0.1),
        'inc_trigger_sell_shares': np.random.uniform(low=0.01, high=0.1),
        'dec_trigger_pct': np.random.uniform(low=0.01, high=0.1),
        'dec_trigger_buy_shares': np.random.uniform(low=0.01, high=0.1),
    }

# %%
traders = [ init_strategy() for _ in range(POP_SIZE) ]

# %%
def fitness(trader, ts):
    # extract strategy
    # run strategy over time series
    # calculate ending value
    
    pass

# %%
def breed(traders):
    # assume traders are sorted
    new_traders = deepcopy(traders)
    
    while True:
        mom_idx = np.random.choice(len(traders))
        dad_idx = np.random.choice(len(traders))
        
        if mom_idx == dad_idx:
            continue
        
        mom = traders[mom_idx]
        dad = traders[dad_idx]
        
        child = dict()
        for prop in mom.keys():
            if np.random.rand() < 0.5:
                child[prop] = mom[prop]
            else:
                child[prop] = dad[prop]
                
        new_traders.append(child)
        
        if len(new_traders) == POP_SIZE:
            break
            
    return new_traders

# %%
def mutate(traders):
    for trader in traders:
        if np.random.rand() < 0.75:
            rand_idx = np.random.choice(len(trader.keys()))
            strat_prop = trader.keys()[rand_idx]
            
            if strat_prop.endswith('shares'):
                trader[strat_prop] = max(trader[strat_prop] + np.random.normal(0.0, 1.0), 0.001)
                
            if strat_prop.endswith('pct'):
                trader[strat_prop] = np.clip(trader[strat_prop] + np.random.normal(0.0, 1.0), a_min=0.001, a_max=0.999)
    
    return traders

# %%
def select(traders):
    scores = [ (trader, fitness(trader)) for trader in traders ]
    scores = sorted(scores, key=lambda x: -x[1])[:int(len(scores)/3)]
    
    return scores
